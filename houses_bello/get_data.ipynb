# %%
import requests
from bs4 import BeautifulSoup

# %%
links_data = pd.read_csv('houses_link.csv')
list_urls = links_data['house link'].tolist()
print(list_urls[:2])
# Out:
# ['/bari/bello/proyecto-nuevo-det-2713018.aspx', '/apartamento-en-venta/bello/paris-det-4629208.aspx']

# %%
main_url = 'https://www.fincaraiz.com.co'
list_urls = [f'{main_url}{url}' for url in list_urls]
list_urls[:2]
# Out:
# ['https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx',
#  'https://www.fincaraiz.com.co/apartamento-en-venta/bello/paris-det-4629208.aspx']

# %%
def get_title_and_price(soup):
    try:
        detail = soup.find('div', attrs={'class':'detailheader'})
    
        title = detail.find('div', attrs={'class', 'title'})
        title_box = title.find('div', attrs={'class', 'box'})
        title_text = title_box.find('h1').text
    
        price = detail.find('div', attrs={'class', 'price'})
        price_text = price.find('h2').text
        
        return title_text, price_text
    except Exception as e:
        pass

# %%
def get_house_features(soup):
    try:
        features = soup.find('div', attrs={'class': 'features'})
        surface = features.find('span', attrs={'class': 'advertSurface'}).text.strip()
        rooms = features.find('span', attrs={'class': 'advertRooms'}).text.strip()
        baths = features.find('span', attrs={'class': 'advertBaths'}).text.strip()
        garages = features.find('span', attrs={'class': 'advertGarages'}).text.strip()
        
        return clean_features_text(surface, rooms, baths, garages)        
    except Exception as e:
        pass

# %%
def get_house_features_2(soup):
    try:
        features_2 = soup.find('div', attrs={'class': 'features_2'})
        features = features_2.find_all('li')
        features = features[:-1]
    
        features_2 = dict()
        for feature in features:
            feature_key = feature.find('b').text
            feature_value = feature.text
            features_2.update({feature_key: feature_value})
        
        return clean_features_2(features_2)
    except Exception as e:
        pass

# %%
def clean_features_text(surface, rooms, baths, garages):
    rooms = rooms[-1:]
    baths = baths[-1:]
    garages = garages[-1:] if garages != 'Sin especificar' else 'nan'
    
    return surface, rooms, baths, garages

# %%
def clean_features_2(features):
    private_area = features.get('Área privada:')
    builded_area = features.get('Área Const.:')
    estrato = features.get('Estrato:')
    antiquity = features.get('Antigüedad:')
    price_by_m = features.get('Precio m²:')
    administration = features.get('Admón:')
    
    private_area = delete_dirty_chars(private_area).split(':')[1] if private_area else 'nan'
    builded_area = delete_dirty_chars(builded_area).split(':')[1] if builded_area else 'nan'
    estrato = delete_dirty_chars(estrato).split(':')[1][0] if estrato else 'nan'
    antiquity = delete_dirty_chars(antiquity).split(':')[1] if antiquity else 'nan'
    price_by_m = delete_dirty_chars(price_by_m).split(':')[1] if price_by_m else 'nan'
    administration = delete_dirty_chars(administration).split(':')[1][0:8] if administration else 'nan'
    
    return (private_area, builded_area, estrato, antiquity, price_by_m, administration)

# %%
def delete_dirty_chars(string):
    return string.replace(' ', '').replace('\n', '').replace('\r', '')

# %%
all_data = []
for index, url in enumerate(list_urls):
    try:
        r = requests.get(url)
        if r.status_code == 404:
            continue
        soup = BeautifulSoup(r.text, 'html.parser')
    
        headers = get_title_and_price(soup)
        features = get_house_features(soup)
        features_2 = get_house_features_2(soup)
    
        house = headers + features + features_2
        all_data.append(house)
    
    except Exception as e:
        continue
    
    print('---------------------------------------------------------')
    print(f'{index}, { url}')
    print('---------------------------------------------------------')
    print(house)
    print('---------------------------------------------------------')
# Out:
# ---------------------------------------------------------
# 0, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 1, https://www.fincaraiz.com.co/apartamento-en-venta/bello/paris-det-4629208.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello paris', '$ 83.000.000', '39,00 m²', '2', '1', 'nan', 'nan', '39,00m²', '2', 'Menosde1año', '2.128.205/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2, https://www.fincaraiz.com.co/apartamento-en-venta/bello/cabanas-det-4688002.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello cabañas', '$ 230.000.000', '69,00 m²', '3', '2', '1', '69,00m²', '69,00m²', '4', '1a8años', '3.333.333/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 3, https://www.fincaraiz.com.co/nordica/bello/proyecto-nuevo-det-4679445.aspx?itemid=4679452
# ---------------------------------------------------------
# ('NORDICA', 'Desde $ 138.850.000 Hasta $ 302.650.000', '36,00 a 82,00 m²', '1', '1', 'nan', '35,00a80,00m²', '36,00a82,00m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 4, https://www.fincaraiz.com.co/apartamento-en-venta/bello/prado-det-4568733.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello prado', '$ 202.508.000', '64,00 m²', '3', '2', '1', '64,00m²', '64,00m²', '3', 'Menosde1año', '3.164.188/m²', '$150,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 5, https://www.fincaraiz.com.co/apartamento-en-venta/bello/cabanas-det-4698330.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Cabañas ', '$ 245.000.000', '71,00 m²', '3', '2', '1', '71,00m²', '71,00m²', '3', 'Menosde1año', '3.450.704/m²', '$100,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 6, https://www.fincaraiz.com.co/cerroclaro/bello/proyecto-nuevo-det-3279414.aspx?itemid=4252067
# ---------------------------------------------------------
# ('Cerroclaro', 'Desde $ 127.599.999 Hasta $ 151.408.450', '54,30 m²', '2', '2', 'nan', '50,20m²', '54,30m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 7, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4721033.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello NIQUIA', '$ 170.000.000', '75,00 m²', '2', '2', 'nan', 'nan', '75,00m²', '3', 'nan', '2.266.667/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 8, https://www.fincaraiz.com.co/montana/bello/proyecto-nuevo-det-2921179.aspx
# ---------------------------------------------------------
# ('MONTANA', 'Desde $ 562.600.000 Hasta $ 602.600.000', '126,14 m²', '3', '4', '2', 'nan', '126,14m²', '4', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 9, https://www.fincaraiz.com.co/nordica/bello/proyecto-nuevo-det-4679445.aspx?itemid=4679448
# ---------------------------------------------------------
# ('NORDICA', 'Desde $ 138.850.000 Hasta $ 302.650.000', '36,00 a 82,00 m²', '1', '1', 'nan', '35,00a80,00m²', '36,00a82,00m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 10, https://www.fincaraiz.com.co/apartamento-en-venta/bello/cabanas-det-4689620.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello cabañas', '$ 187.000.000', '55,00 m²', '3', '2', '1', '55,00m²', '55,00m²', '4', 'Menosde1año', '3.400.000/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 11, https://www.fincaraiz.com.co/apartamento-en-venta/bello/nordica-det-4724395.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Nórdica', '$ 250.000.000', '60,00 m²', '3', '2', '1', '60,00m²', '60,00m²', '3', '1a8años', '4.166.667/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 12, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-4724359.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello BELLO', '$ 225.000.000', '62,00 m²', '3', '2', '1', '62,00m²', '62,00m²', '4', 'Menosde1año', '3.629.032/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 13, https://www.fincaraiz.com.co/apartamento-en-venta/bello/santa_ana-det-4724094.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Santa Ana', '$ 230.000.000', '62,00 m²', '3', '2', '1', '62,00m²', '62,00m²', '4', 'Menosde1año', '3.709.677/m²', '$140,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 14, https://www.fincaraiz.com.co/cerroclaro/bello/proyecto-nuevo-det-3279414.aspx?itemid=4252064
# ---------------------------------------------------------
# ('Cerroclaro', 'Desde $ 127.599.999 Hasta $ 151.408.450', '54,30 m²', '2', '2', 'nan', '50,20m²', '54,30m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 15, https://www.fincaraiz.com.co/apartamento-en-venta/bello/santa_ana-det-4723998.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Santa Ana', '$ 230.000.000', '62,00 m²', '3', '2', '1', '62,00m²', '62,00m²', '4', 'Menosde1año', '3.709.677/m²', '$140,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 16, https://www.fincaraiz.com.co/florida-norteamerica/bello/proyecto-nuevo-det-2564055.aspx
# ---------------------------------------------------------
# ('Florida Norteamerica', 'Desde $ 186.460.000 Hasta $ 260.000.000', '56,92 a 89,63 m²', '3', '2', 'nan', 'nan', '56,92a89,63m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 17, https://www.fincaraiz.com.co/nordica/bello/proyecto-nuevo-det-4679445.aspx?itemid=4679449
# ---------------------------------------------------------
# ('NORDICA', 'Desde $ 138.850.000 Hasta $ 302.650.000', '36,00 a 82,00 m²', '1', '1', 'nan', '35,00a80,00m²', '36,00a82,00m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 18, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-4596747.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello BELLO', '$ 182.000.000', '50,00 m²', '2', '2', '1', '45,00m²', '50,00m²', '3', '1a8años', '3.640.000/m²', '$148,290')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 19, https://www.fincaraiz.com.co/apartamento-en-venta/bello/apartaestudio_iluminado_cabanas-det-4717362.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello APARTAESTUDIO ILUMINADO EN CABAÑAS', '$ 80.000.000', '35,00 m²', '1', '1', 'nan', 'nan', '35,00m²', '3', '9a15años', '2.285.714/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 20, https://www.fincaraiz.com.co/cerroclaro/bello/proyecto-nuevo-det-3279414.aspx?itemid=4252063
# ---------------------------------------------------------
# ('Cerroclaro', 'Desde $ 127.599.999 Hasta $ 151.408.450', '54,30 m²', '2', '2', 'nan', '50,20m²', '54,30m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 21, https://www.fincaraiz.com.co/apartamento-en-venta/bello/trapiche-det-4713731.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello El Trapiche', '$ 86.000.000', '48,00 m²', '2', '1', 'nan', 'nan', '48,00m²', '2', 'Menosde1año', '1.791.667/m²', '$73,500E')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 22, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello_centro-det-3376777.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Bello Centro', '$ 236.000.000', '71,00 m²', '3', '2', '1', 'nan', '71,00m²', '3', '1a8años', '3.323.944/m²', '$185,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 23, https://www.fincaraiz.com.co/cerroclaro/bello/proyecto-nuevo-det-3279414.aspx?itemid=4252068
# ---------------------------------------------------------
# ('Cerroclaro', 'Desde $ 127.599.999 Hasta $ 151.408.450', '54,30 m²', '2', '2', 'nan', '50,20m²', '54,30m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 24, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4535243.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello NIQUIA', '$ 265.000.000', '70,00 m²', '3', '2', '1', '70,00m²', '70,00m²', '3', 'nan', '3.785.714/m²', '$150,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 25, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4719009.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Niquia', '$ 190.000.000', '62,00 m²', '2', '2', '1', '62,00m²', '62,00m²', '4', '1a8años', '3.064.516/m²', '$188,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 26, https://www.fincaraiz.com.co/cerroclaro/bello/proyecto-nuevo-det-3279414.aspx?itemid=4252066
# ---------------------------------------------------------
# ('Cerroclaro', 'Desde $ 127.599.999 Hasta $ 151.408.450', '54,30 m²', '2', '2', 'nan', '50,20m²', '54,30m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 27, https://www.fincaraiz.com.co/florida-norteamerica/bello/proyecto-nuevo-det-2564055.aspx?itemid=2622970
# ---------------------------------------------------------
# ('Florida Norteamerica', 'Desde $ 186.460.000 Hasta $ 260.000.000', '56,92 a 89,63 m²', '3', '2', 'nan', 'nan', '56,92a89,63m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 28, https://www.fincaraiz.com.co/florida-norteamerica/bello/proyecto-nuevo-det-2564055.aspx?itemid=3344001
# ---------------------------------------------------------
# ('Florida Norteamerica', 'Desde $ 186.460.000 Hasta $ 260.000.000', '56,92 a 89,63 m²', '3', '2', 'nan', 'nan', '56,92a89,63m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 29, https://www.fincaraiz.com.co/nordica/bello/proyecto-nuevo-det-4679445.aspx?itemid=4679450
# ---------------------------------------------------------
# ('NORDICA', 'Desde $ 138.850.000 Hasta $ 302.650.000', '36,00 a 82,00 m²', '1', '1', 'nan', '35,00a80,00m²', '36,00a82,00m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 30, https://www.fincaraiz.com.co/apartamento-en-venta/bello/madera-det-4718724.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Madera', '$ 153.000.000', '58,00 m²', '3', '2', 'nan', '58,00m²', '58,00m²', '4', '1a8años', '2.637.931/m²', '$138,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 31, https://www.fincaraiz.com.co/florida-norteamerica/bello/proyecto-nuevo-det-2564055.aspx?itemid=3670875
# ---------------------------------------------------------
# ('Florida Norteamerica', 'Desde $ 186.460.000 Hasta $ 260.000.000', '56,92 a 89,63 m²', '3', '2', 'nan', 'nan', '56,92a89,63m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 32, https://www.fincaraiz.com.co/nordica/bello/proyecto-nuevo-det-4679445.aspx?itemid=4679453
# ---------------------------------------------------------
# ('NORDICA', 'Desde $ 138.850.000 Hasta $ 302.650.000', '36,00 a 82,00 m²', '1', '1', 'nan', '35,00a80,00m²', '36,00a82,00m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 33, https://www.fincaraiz.com.co/apartamento-en-venta/bello/andalucia-det-4718253.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Andalucia', '$ 140.000.000', '72,00 m²', '3', '2', 'nan', '72,00m²', '72,00m²', '3', '1a8años', '1.944.444/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 34, https://www.fincaraiz.com.co/apartamento-en-venta/bello/vende_hermoso_apartamento_barrio_obrero-det-4718109.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello SE VENDE HERMOSO APARTAMENTO EN EL BARRIO OBRERO', '$ 190.000.000', '68,00 m²', '3', '2', '1', 'nan', '68,00m²', '4', '1a8años', '2.794.118/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 35, https://www.fincaraiz.com.co/c26/bello/proyecto-nuevo-det-4383848.aspx?itemid=4383852
# ---------------------------------------------------------
# ('C26', 'Desde $ 190.250.000 Hasta $ 268.756.000', '47,50 a 71,42 m²', '1', '1', '1', 'nan', '47,50a71,42m²', '4', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 36, https://www.fincaraiz.com.co/florida-norteamerica/bello/proyecto-nuevo-det-2564055.aspx?itemid=4074277
# ---------------------------------------------------------
# ('Florida Norteamerica', 'Desde $ 186.460.000 Hasta $ 260.000.000', '56,92 a 89,63 m²', '3', '2', 'nan', 'nan', '56,92a89,63m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 37, https://www.fincaraiz.com.co/florida-norteamerica/bello/proyecto-nuevo-det-2564055.aspx?itemid=4074280
# ---------------------------------------------------------
# ('Florida Norteamerica', 'Desde $ 186.460.000 Hasta $ 260.000.000', '56,92 a 89,63 m²', '3', '2', 'nan', 'nan', '56,92a89,63m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 38, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4691592.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Niquia', '$ 189.000.000', '69,00 m²', '3', '2', '1', '63,00m²', '69,00m²', '4', 'Menosde1año', '2.739.130/m²', '$120,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 39, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4717390.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Niquía', '$ 248.000.000', '101,00 m²', '5', '2', 'nan', 'nan', '101,00m²', '3', 'nan', '2.455.446/m²', '$73,000E')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 41, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4422176.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello NIQUIA', '$ 185.000.000', '104,00 m²', '3', '2', '1', 'nan', '104,00m²', '3', 'nan', '1.778.846/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 42, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4716383.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello NIQUIA', '$ 155.000.000', '70,00 m²', '3', '1', 'nan', '70,00m²', '70,00m²', '3', '9a15años', '2.214.286/m²', '$69,000E')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 43, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4716264.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Niquia ', '$ 190.000.000', '56,00 m²', '3', '2', '1', 'nan', '56,00m²', '3', 'Menosde1año', '3.392.857/m²', '$140,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 44, https://www.fincaraiz.com.co/apartamento-en-venta/bello/cabanita-det-4715680.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello La Cabañita', '$ 240.000.000', '97,00 m²', '3', '2', '1', 'nan', '97,00m²', '4', '9a15años', '2.474.227/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 45, https://www.fincaraiz.com.co/apartamento-en-venta/bello/norte_america-det-4582877.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Norte America', '$ 299.000.000', '85,00 m²', '3', '2', '1', '101,00m²', '85,00m²', '4', 'Menosde1año', '3.517.647/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 46, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3437297
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 47, https://www.fincaraiz.com.co/apartamento-en-venta/bello/barrio_obrero-det-4714672.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Barrio obrero', '$ 183.000.000', '68,00 m²', '3', '2', 'nan', 'nan', '68,00m²', 'nan', 'nan', '2.691.176/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 48, https://www.fincaraiz.com.co/montana/bello/proyecto-nuevo-det-2921179.aspx
# ---------------------------------------------------------
# ('MONTANA', 'Desde $ 562.600.000 Hasta $ 602.600.000', '126,14 m²', '3', '4', '2', 'nan', '126,14m²', '4', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 49, https://www.fincaraiz.com.co/apartamento-en-venta/bello/paris-det-4629208.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello paris', '$ 83.000.000', '39,00 m²', '2', '1', 'nan', 'nan', '39,00m²', '2', 'Menosde1año', '2.128.205/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 50, https://www.fincaraiz.com.co/apartamento-en-venta/bello/cabanita-det-4715680.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello La Cabañita', '$ 240.000.000', '97,00 m²', '3', '2', '1', 'nan', '97,00m²', '4', '9a15años', '2.474.227/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 51, https://www.fincaraiz.com.co/c26/bello/proyecto-nuevo-det-4383848.aspx?itemid=4383879
# ---------------------------------------------------------
# ('C26', 'Desde $ 190.250.000 Hasta $ 268.756.000', '47,50 a 71,42 m²', '1', '1', '1', 'nan', '47,50a71,42m²', '4', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 52, https://www.fincaraiz.com.co/apartamento-en-venta/bello/prado-det-4568733.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello prado', '$ 202.508.000', '64,00 m²', '3', '2', '1', '64,00m²', '64,00m²', '3', 'Menosde1año', '3.164.188/m²', '$150,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 53, https://www.fincaraiz.com.co/apartamento-en-venta/bello/madera_bello-det-4712683.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello La madera Bello', '$ 172.000.000', '58,00 m²', '2', '2', 'nan', '58,00m²', '58,00m²', '3', '1a8años', '2.965.517/m²', '$116,950')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 54, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862512
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 55, https://www.fincaraiz.com.co/poblado-niquia/bello/proyecto-nuevo-det-783906.aspx?itemid=2169233
# ---------------------------------------------------------
# ('POBLADO NIQUÍA', 'Desde $ 229.850.000 Hasta $ 257.276.000', '70,76 a 78,69 m²', '3', '2', '1', '62,85a69,91m²', '70,76a78,69m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 56, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 57, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862513
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 58, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3360180
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 59, https://www.fincaraiz.com.co/poblado-niquia/bello/proyecto-nuevo-det-783906.aspx?itemid=3301642
# ---------------------------------------------------------
# ('POBLADO NIQUÍA', 'Desde $ 229.850.000 Hasta $ 257.276.000', '70,76 a 78,69 m²', '3', '2', '1', '62,85a69,91m²', '70,76a78,69m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 60, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=1845080
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 61, https://www.fincaraiz.com.co/poblado-niquia/bello/proyecto-nuevo-det-783906.aspx?itemid=2453032
# ---------------------------------------------------------
# ('POBLADO NIQUÍA', 'Desde $ 229.850.000 Hasta $ 257.276.000', '70,76 a 78,69 m²', '3', '2', '1', '62,85a69,91m²', '70,76a78,69m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 62, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862482
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 63, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=4641190
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 64, https://www.fincaraiz.com.co/florida-norteamerica/bello/proyecto-nuevo-det-2564055.aspx
# ---------------------------------------------------------
# ('Florida Norteamerica', 'Desde $ 186.460.000 Hasta $ 260.000.000', '56,92 a 89,63 m²', '3', '2', 'nan', 'nan', '56,92a89,63m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 65, https://www.fincaraiz.com.co/c26/bello/proyecto-nuevo-det-4383848.aspx?itemid=4383880
# ---------------------------------------------------------
# ('C26', 'Desde $ 190.250.000 Hasta $ 268.756.000', '47,50 a 71,42 m²', '1', '1', '1', 'nan', '47,50a71,42m²', '4', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 66, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4713994.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Niquia', '$ 180.000.000', '65,00 m²', '3', '1', 'nan', 'nan', '65,00m²', '3', 'Menosde1año', '2.769.231/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 67, https://www.fincaraiz.com.co/apartamento-en-venta/bello/cumbres-det-4345245.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Cumbres', '$ 173.000.000', '76,00 m²', '3', '2', '1', 'nan', '76,00m²', '3', '1a8años', '2.276.316/m²', '$50,000E')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 68, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862517
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 69, https://www.fincaraiz.com.co/poblado-niquia/bello/proyecto-nuevo-det-783906.aspx?itemid=3301666
# ---------------------------------------------------------
# ('POBLADO NIQUÍA', 'Desde $ 229.850.000 Hasta $ 257.276.000', '70,76 a 78,69 m²', '3', '2', '1', '62,85a69,91m²', '70,76a78,69m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 70, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3437273
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 71, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862514
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 72, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-4251147.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello BELLO', '$ 180.000.000', '57,00 m²', '3', '1', '1', '57,00m²', '57,00m²', '3', 'Menosde1año', '3.157.895/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 73, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3437293
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 74, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862516
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 75, https://www.fincaraiz.com.co/apartamento-en-venta/bello/norteamerica-det-4296445.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello NORTEAMERICA', '$ 275.000.000', '88,00 m²', '3', '2', '1', 'nan', '88,00m²', '4', '1a8años', '3.125.000/m²', '$198,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 76, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-4294505.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello BELLO', '$ 310.000.000', '70,00 m²', '3', '2', '1', 'nan', '70,00m²', '4', 'nan', '4.428.571/m²', '$210,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 77, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862499
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 78, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3289444
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 79, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-4257783.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello BELLO', '$ 242.000.000', '70,00 m²', '3', '2', '1', 'nan', '70,00m²', 'nan', 'nan', '3.457.143/m²', '$130,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 80, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862496
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 81, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3289445
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 82, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=1845085
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 83, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2713429
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 84, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3437295
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 85, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=1845086
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 86, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3437298
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 87, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3437290
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 88, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3360181
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 89, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3289448
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 90, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=1845081
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 91, https://www.fincaraiz.com.co/apartamento-en-venta/bello/florida_norteamerica-det-4483972.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello FLORIDA NORTEAMERICA', '$ 350.000.000', '103,00 m²', '3', '2', '1', 'nan', '103,00m²', 'nan', 'nan', '3.398.058/m²', '$198,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 92, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4498704.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello NIQUIA', '$ 370.000.000', '91,00 m²', '3', '2', '2', 'nan', '91,00m²', '5', '1a8años', '4.065.934/m²', '$196,500')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 93, https://www.fincaraiz.com.co/apartamento-en-venta/bello/madera_bello-det-4712683.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello La madera Bello', '$ 172.000.000', '58,00 m²', '2', '2', 'nan', '58,00m²', '58,00m²', '3', '1a8años', '2.965.517/m²', '$116,950')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 94, https://www.fincaraiz.com.co/apartamento-en-venta/bello/las_cabanas-det-4573003.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Las Cabañas', '$ 210.000.000', '55,00 m²', '3', '2', '1', 'nan', '55,00m²', 'nan', 'nan', '3.818.182/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 95, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4722541.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Niquia', '$ 150.000.000', '58,00 m²', '3', '2', 'nan', 'nan', '58,00m²', '3', 'nan', '2.586.207/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 96, https://www.fincaraiz.com.co/montana/bello/proyecto-nuevo-det-2921179.aspx
# ---------------------------------------------------------
# ('MONTANA', 'Desde $ 562.600.000 Hasta $ 602.600.000', '126,14 m²', '3', '4', '2', 'nan', '126,14m²', '4', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 97, https://www.fincaraiz.com.co/apartamento-en-venta/bello/paris-det-4629208.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello paris', '$ 83.000.000', '39,00 m²', '2', '1', 'nan', 'nan', '39,00m²', '2', 'Menosde1año', '2.128.205/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 98, https://www.fincaraiz.com.co/apartamento-en-venta/bello/cabanita-det-4715680.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello La Cabañita', '$ 240.000.000', '97,00 m²', '3', '2', '1', 'nan', '97,00m²', '4', '9a15años', '2.474.227/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 99, https://www.fincaraiz.com.co/c26/bello/proyecto-nuevo-det-4383848.aspx?itemid=4383879
# ---------------------------------------------------------
# ('C26', 'Desde $ 190.250.000 Hasta $ 268.756.000', '47,50 a 71,42 m²', '1', '1', '1', 'nan', '47,50a71,42m²', '4', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 100, https://www.fincaraiz.com.co/apartamento-en-venta/bello/prado-det-4568733.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello prado', '$ 202.508.000', '64,00 m²', '3', '2', '1', '64,00m²', '64,00m²', '3', 'Menosde1año', '3.164.188/m²', '$150,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 101, https://www.fincaraiz.com.co/apartamento-en-venta/bello/madera_bello-det-4712683.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello La madera Bello', '$ 172.000.000', '58,00 m²', '2', '2', 'nan', '58,00m²', '58,00m²', '3', '1a8años', '2.965.517/m²', '$116,950')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 102, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862482
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 103, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-4712251.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Niquia', '$ 245.000.000', '66,00 m²', '3', '2', '1', 'nan', '66,00m²', '4', 'Menosde1año', '3.712.121/m²', '$150,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 104, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 105, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862499
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 106, https://www.fincaraiz.com.co/apartamento-en-venta/bello/villa_norte-det-4712229.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Villa Norte', '$ 140.000.000', '62,00 m²', '3', '1', 'nan', '62,00m²', '62,00m²', '3', '16a30años', '2.258.065/m²', '$100,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 107, https://www.fincaraiz.com.co/apartamento-en-venta/bello/gangazo_cabanitas-det-4718391.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello GANGAZO EN CABAÑITAS', '$ 190.000.000', '110,00 m²', '4', '2', 'nan', 'nan', '110,00m²', '3', '1a8años', '1.727.273/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 108, https://www.fincaraiz.com.co/apartamento-en-venta/bello/estacion_madera-det-4714934.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello estacion madera', '$ 200.000.000', '56,00 m²', '3', '2', '1', '56,00m²', '56,00m²', '3', '1a8años', '3.571.429/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 109, https://www.fincaraiz.com.co/apartamento-en-venta/bello/madera-det-4717958.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello LA MADERA', '$ 140.000.000', '61,00 m²', '3', '2', 'nan', '61,00m²', '61,00m²', '3', 'Menosde1año', '2.295.082/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 110, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862517
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 111, https://www.fincaraiz.com.co/apartamento-en-venta/bello/conjunto_puerta_madera-det-4692914.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Conjunto Puerta Madera', '$ 230.000.000', '64,00 m²', '3', '2', '1', '64,00m²', '64,00m²', '3', '1a8años', '3.593.750/m²', '$143,500')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 112, https://www.fincaraiz.com.co/florida-norteamerica/bello/proyecto-nuevo-det-2564055.aspx
# ---------------------------------------------------------
# ('Florida Norteamerica', 'Desde $ 186.460.000 Hasta $ 260.000.000', '56,92 a 89,63 m²', '3', '2', 'nan', 'nan', '56,92a89,63m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 113, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862516
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 114, https://www.fincaraiz.com.co/apartamento-en-venta/bello/conjunto_puerta_madera-det-4390468.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Conjunto Puerta Madera', '$ 155.000.000', '59,00 m²', '3', '2', 'nan', '59,00m²', '59,00m²', '3', '1a8años', '2.627.119/m²', '$129,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 115, https://www.fincaraiz.com.co/apartamento-en-venta/bello/conjunto_puerta_madera-det-4207994.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Conjunto Puerta Madera', '$ 179.000.000', '59,00 m²', '3', '2', '1', '59,00m²', '59,00m²', '3', '1a8años', '3.033.898/m²', '$130,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 116, https://www.fincaraiz.com.co/c26/bello/proyecto-nuevo-det-4383848.aspx?itemid=4383880
# ---------------------------------------------------------
# ('C26', 'Desde $ 190.250.000 Hasta $ 268.756.000', '47,50 a 71,42 m²', '1', '1', '1', 'nan', '47,50a71,42m²', '4', 'nan', 'nan', 'nan')
# ...
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2328, https://www.fincaraiz.com.co/montana/bello/proyecto-nuevo-det-2921179.aspx
# ---------------------------------------------------------
# ('MONTANA', 'Desde $ 562.600.000 Hasta $ 602.600.000', '126,14 m²', '3', '4', '2', 'nan', '126,14m²', '4', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2329, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862511
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2330, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-2851006.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Bello', '$ 190.000.000', '60,00 m²', '3', '2', 'nan', 'nan', '60,00m²', '4', 'nan', '3.166.667/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2331, https://www.fincaraiz.com.co/apartamento-en-venta/bello/madera-det-2850929.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Madera', '$ 177.000.000', '66,00 m²', '3', '2', 'nan', 'nan', '66,00m²', '4', 'nan', '2.681.818/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2332, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-2851096.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Bello', '$ 190.000.000', '57,00 m²', '3', '1', 'nan', 'nan', '57,00m²', '3', 'nan', '3.333.333/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2333, https://www.fincaraiz.com.co/apartamento-en-venta/bello/obrero-det-2793934.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello obrero', '$ 165.000.000', '65,00 m²', '3', '2', 'nan', 'nan', '65,00m²', '3', '1a8años', '2.538.462/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2334, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862510
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2335, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-2768681.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello bello', '$ 167.000.000', '62,00 m²', '3', '2', 'nan', 'nan', '62,00m²', '4', '1a8años', '2.693.548/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2336, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2337, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862509
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2338, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-2806195.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello BELLO', '$ 145.000.000', '58,00 m²', '3', '2', '1', '58,00m²', '58,00m²', '4', 'Menosde1año', '2.500.000/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2339, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=1845081
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2340, https://www.fincaraiz.com.co/apartamento-en-venta/bello/mirador-det-2783626.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello EL MIRADOR', '$ 137.000.000', '54,00 m²', '3', '2', '1', 'nan', '54,00m²', '3', 'nan', '2.537.037/m²', '$98,000E')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2341, https://www.fincaraiz.com.co/apartamento-en-venta/bello/barrio_nuevo-det-2753667.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello BARRIO NUEVO', '$ 150.000.000', '69,00 m²', '3', '2', 'nan', 'nan', '69,00m²', '3', '1a8años', '2.173.913/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2342, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862500
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2343, https://www.fincaraiz.com.co/apartamento-en-venta/bello/parque-det-2747005.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello EL PARQUE', '$ 210.000.000', '60,00 m²', '3', '2', 'nan', 'nan', '60,00m²', '4', 'nan', '3.500.000/m²', '$200,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2344, https://www.fincaraiz.com.co/apartamento-en-venta/bello/cabanas_garaje_180-det-3605513.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello CABAÑAS GARAJE 180', '$ 180.000.000', '77,00 m²', '3', '2', '1', '77,00m²', '77,00m²', '3', 'Menosde1año', '2.337.662/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2345, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2713431
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2346, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-2794574.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello bello', '$ 140.000.000', '72,00 m²', '3', '2', 'nan', 'nan', '72,00m²', '3', '1a8años', '1.944.444/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2347, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bellavista-det-3603036.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Bellavista', '$ 120.000.000', '55,00 m²', '3', '2', 'nan', '55,00m²', '55,00m²', '3', '1a8años', '2.181.818/m²', '$100,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2348, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862497
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2349, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-2795045.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello bello', '$ 290.000.000', '294,00 m²', '4', '1', 'nan', 'nan', '294,00m²', '3', '1a8años', '986.395/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2350, https://www.fincaraiz.com.co/apartamento-en-venta/bello/norte_ameria-det-3562071.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello norte ameria', '$ 145.000.000', '39,00 m²', '1', '1', '1', '39,00m²', '39,00m²', '4', 'Menosde1año', '3.717.949/m²', '$84,511E')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2351, https://www.fincaraiz.com.co/bari/bello/proyecto-nuevo-det-2713018.aspx?itemid=2862519
# ---------------------------------------------------------
# ('BARI', 'Desde $ 179.808.000 Hasta $ 189.108.000', '64,11 m²', '3', '2', 'nan', '60,90m²', '64,11m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2352, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-2699102.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello bello', '$ 207.000.000', '60,00 m²', '3', '2', 'nan', 'nan', '60,00m²', '4', '1a8años', '3.450.000/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2353, https://www.fincaraiz.com.co/apartamento-en-venta/bello/cabanitas-det-3518992.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello cabañitas', '$ 200.000.000', '105,00 m²', '4', '3', 'nan', 'nan', '105,00m²', '4', '9a15años', '1.904.762/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2354, https://www.fincaraiz.com.co/reserva-de-bucaros/bello/proyecto-nuevo-det-841683.aspx?itemid=3289448
# ---------------------------------------------------------
# ('RESERVA DE BÚCAROS', 'Desde $ 151.012.000 Hasta $ 313.871.000', '43,60 a 105,60 m²', '1', '2', '1', '38,94a97,21m²', '43,60a105,60m²', '3', 'nan', 'nan', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2355, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia-det-2669497.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello niquia', '$ 280.000.000', '92,00 m²', '3', '2', 'nan', 'nan', '92,00m²', '3', 'nan', '3.043.478/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2356, https://www.fincaraiz.com.co/apartamento-en-venta/bello/cabanas-det-3477740.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello cabañas', '$ 250.000.000', '72,00 m²', '3', '2', '1', 'nan', '72,00m²', '3', 'Menosde1año', '3.472.222/m²', '$170,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2357, https://www.fincaraiz.com.co/apartamento-en-venta/bello/molinares-det-2705795.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello molinares', '$ 225.000.000', '60,00 m²', '3', '2', 'nan', 'nan', '60,00m²', '3', 'Menosde1año', '3.750.000/m²', '$120,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2358, https://www.fincaraiz.com.co/apartamento-en-venta/bello/estacion_madera-det-2669147.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello ESTACIÓN MADERA', '$ 195.000.000', '64,00 m²', '2', '2', 'nan', 'nan', '64,00m²', '3', 'nan', '3.046.875/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2359, https://www.fincaraiz.com.co/apartamento-en-venta/bello/prado-det-2624422.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello El Prado', '$ 167.000.000', '6,00 m²', '3', '2', '1', 'nan', '6,00m²', '3', 'Menosde1año', '27.833.333/m²', '$150,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2360, https://www.fincaraiz.com.co/apartamento-en-venta/bello/bello-det-2567191.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Bello', '$ 128.000.000', '50,00 m²', '2', '2', 'nan', '50,00m²', '50,00m²', '3', 'nan', '2.560.000/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2361, https://www.fincaraiz.com.co/apartamento-en-venta/bello/villa_sol-det-3345534.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Villa Sol', '$ 110.000.000', '54,00 m²', '3', '2', 'nan', 'nan', '54,00m²', '3', '1a8años', '2.037.037/m²', '$98,000E')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2362, https://www.fincaraiz.com.co/apartamento-en-venta/bello/villa_del_sol-det-3337775.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Villa del Sol', '$ 145.000.000', '60,00 m²', '3', '2', '1', 'nan', '60,00m²', '3', 'nan', '2.416.667/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2363, https://www.fincaraiz.com.co/apartamento-en-venta/bello/niquia_puerta_del_norte-det-3327837.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Niquía Puerta del Norte', '$ 249.000.000', '65,00 m²', '3', '2', '1', '65,00m²', '65,00m²', '4', 'Menosde1año', '3.830.769/m²', 'nan')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2364, https://www.fincaraiz.com.co/apartamento-en-venta/bello/madera-det-2527159.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello MADERA', '$ 170.000.000', '65,00 m²', '2', '2', '1', '65,00m²', '65,00m²', '3', '1a8años', '2.615.385/m²', '$123,000')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2365, https://www.fincaraiz.com.co/apartamento-en-venta/bello/villas_del_sol-det-3194701.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello Villas del Sol', '$ 110.000.000', '56,00 m²', '3', '2', 'nan', 'nan', '56,00m²', '3', '1a8años', '1.964.286/m²', '$95,000E')
# ---------------------------------------------------------
# ---------------------------------------------------------
# 2366, https://www.fincaraiz.com.co/apartamento-en-venta/bello/navarra-det-3080034.aspx
# ---------------------------------------------------------
# ('Apartamento en Venta Bello navarra', '$ 170.000.000', '65,00 m²', '3', '2', '1', 'nan', '65,00m²', '4', '1a8años', '2.615.385/m²', '$170,000')
# ---------------------------------------------------------

# %%
columns = ['title', 'price', 'surface', 'rooms', 'baths', 'garages', 'private area',
           'builded area', 'estrato', 'antiquity', 'price m2', 'administration']
data_frame = pd.DataFrame(all_data, columns=columns)

# %%
data_frame.to_csv('bello_houses.csv', index=False, encoding='utf-8')
