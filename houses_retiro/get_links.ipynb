# %%
import requests
from bs4 import BeautifulSoup

# %%
main_url = 'https://www.fincaraiz.com.co/apartamentos/venta/el-retiro/?ad=30|1||||1||8|||55|5500013||||||||||||||||1|||1||griddate%20desc||||||'

# %%
def change_url_paginator_value(url, index):
    new_list = list(url)
    new_list[65] = str(index)
    return ''.join(new_list)

# %%
all_houses = []
for index in range(1, 8):
    local_url = change_url_paginator_value(main_url, index)
    r = requests.get(local_url)
    soup = BeautifulSoup(r.text, 'html.parser')
    houses = soup.find_all('ul', attrs={'class': 'advert'})
    all_houses.extend(houses)

# %%
all_houses_links = []
for house in all_houses:
    try:
        link = house.find('img', attrs={'class': 'lazy'})['onclick']
        link = ''.join(list(link)[26:-1])
        all_houses_links.append(link)
    except Exception as e:
        pass

# %%
all_houses_links
# Out:
# ['/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4705196.aspx',
#  '/apartamento-en-venta/el-retiro/bosques_normandia-det-4635130.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283009',
#  '/apartamento-en-venta/el-retiro/pantanillo-det-4723099.aspx',
#  '/apartamento-en-venta/el-retiro/retiro_del_viento-det-4632722.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695065',
#  '/apartamento-en-venta/el-retiro/fizebad-det-4256606.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695068',
#  '/apartamento-en-venta/el-retiro/retiro-det-4256546.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4624540.aspx',
#  '/apartamento-en-venta/el-retiro/fizebad-det-3080407.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4727595.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283008',
#  '/apartamento-en-venta/el-retiro/retiro-det-4305044.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283010',
#  '/apartamento-en-venta/el-retiro/pantanillo-det-4723031.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4579799.aspx',
#  '/apartamento-en-venta/el-retiro/aldea-det-3612530.aspx?itemid=3612530',
#  '/apartamento-en-venta/el-retiro/oriente_antioqueno-det-4709147.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4711423.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695066',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695067',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695068',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695067',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695065',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695066',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283014',
#  '/apartamento-en-venta/el-retiro/unidad_retiro_verde-det-4705030.aspx',
#  '/apartamento-en-venta/el-retiro/fizebad-det-4613735.aspx',
#  '/apartamento-en-venta/el-retiro/aldea-det-3612530.aspx?itemid=3612530',
#  '/apartamento-en-venta/el-retiro/retiro-det-4721129.aspx',
#  '/apartamento-en-venta/el-retiro/zona_urbana-det-4307669.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4687765.aspx',
#  '/apartamento-en-venta/el-retiro/bosques_normandia-det-3238816.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4316700.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3379363.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4378200.aspx',
#  '/apartamento-en-venta/el-retiro/via_don_diego_ceja-det-4687887.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4618726.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4632545.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4339510.aspx',
#  '/apartamento-en-venta/el-retiro/aldea-det-3612530.aspx?itemid=3612530',
#  '/apartamento-en-venta/el-retiro/carrizales-det-4618505.aspx',
#  '/apartamento-en-venta/el-retiro/parque-det-4644859.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695066',
#  '/apartamento-en-venta/el-retiro/retiro-det-4687800.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283010',
#  '/apartamento-en-venta/el-retiro/retiro-det-4636606.aspx',
#  '/apartamento-en-venta/el-retiro/bicentenario-det-4576413.aspx',
#  '/apartamento-en-venta/el-retiro/via_pantanillo-det-4618013.aspx',
#  '/apartamento-en-venta/el-retiro/puro_cuero-det-4609442.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283008',
#  '/apartamento-en-venta/el-retiro/retiro-det-4637576.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283009',
#  '/apartamento-en-venta/el-retiro/fizebad-det-3216997.aspx',
#  '/apartamento-en-venta/el-retiro/via_pantanillo-det-4602253.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695067',
#  '/apartamento-en-venta/el-retiro/via-det-4602107.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4620978.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695065',
#  '/apartamento-en-venta/el-retiro/retiro-det-4610163.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4481840.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695068',
#  '/apartamento-en-venta/el-retiro/retiro-det-4589679.aspx',
#  '/apartamento-en-venta/el-retiro/chagualos-det-4469189.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283014',
#  '/apartamento-en-venta/el-retiro/retiro-det-4583038.aspx',
#  '/apartamento-en-venta/el-retiro/pempenao-det-4593072.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4575974.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283014',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283008',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283009',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283010',
#  '/apartamento-en-venta/el-retiro/retiro-det-4605782.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4588090.aspx',
#  '/apartamento-en-venta/el-retiro/zona_urbana-det-4537246.aspx',
#  '/apartamento-en-venta/el-retiro/retiro_maria-det-3721151.aspx',
#  '/apartamento-en-venta/el-retiro/sierra_grande-det-4639743.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4564821.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4562979.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695065',
#  '/apartamento-en-venta/el-retiro/retiro-det-4263262.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4565296.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283014',
#  '/apartamento-en-venta/el-retiro/via_pantanillo-det-4632956.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283008',
#  '/apartamento-en-venta/el-retiro/retiro-det-4597849.aspx',
#  '/apartamento-en-venta/el-retiro/acuarela-det-4558225.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4624509.aspx',
#  '/apartamento-en-venta/el-retiro/plan-det-4612460.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695066',
#  '/apartamento-en-venta/el-retiro/via_maria-det-4579109.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283010',
#  '/apartamento-en-venta/el-retiro/retiro-det-4571802.aspx',
#  '/apartamento-en-venta/el-retiro/sierragrande-det-4590626.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695067',
#  '/apartamento-en-venta/el-retiro/retiro-det-4183897.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4564865.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695068',
#  '/apartamento-en-venta/el-retiro/retiro-det-4582814.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4595757.aspx',
#  '/apartamento-en-venta/el-retiro/aldea-det-3612530.aspx?itemid=3612530',
#  '/apartamento-en-venta/el-retiro/retiro-det-4584536.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4563100.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283009',
#  '/apartamento-en-venta/el-retiro/fizebad-det-4585775.aspx',
#  '/apartamento-en-venta/el-retiro/carabanchel-det-4527455.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4552748.aspx',
#  '/apartamento-en-venta/el-retiro/calle-det-4522321.aspx',
#  '/apartamento-en-venta/el-retiro/pempenao-det-4489382.aspx',
#  '/apartamento-en-venta/el-retiro/bicentenrio-det-4465853.aspx',
#  '/apartamento-en-venta/el-retiro/bicentenario-det-4514362.aspx',
#  '/apartamento-en-venta/el-retiro/via_pantanillo-det-4531992.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4531868.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4515242.aspx',
#  '/apartamento-en-venta/el-retiro/bosques_normandia-det-4545290.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4464139.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4516809.aspx',
#  '/apartamento-en-venta/el-retiro/zona_urbana-det-4488698.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695065',
#  '/apartamento-en-venta/el-retiro/retiro-det-4507887.aspx',
#  '/apartamento-en-venta/el-retiro/bicenterio-det-4478234.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283014',
#  '/apartamento-en-venta/el-retiro/cerca_parque-det-4484799.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695067',
#  '/apartamento-en-venta/el-retiro/pantanillo-det-4257890.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4520905.aspx',
#  '/apartamento-en-venta/el-retiro/aldea-det-4466040.aspx',
#  '/apartamento-en-venta/el-retiro/fizebad-det-4457143.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695066',
#  '/apartamento-en-venta/el-retiro/puro_cuero-det-4455295.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283008',
#  '/apartamento-en-venta/el-retiro/retiro-det-4508226.aspx',
#  '/apartamento-en-venta/el-retiro/retiro_del_viento-det-4464939.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695068',
#  '/apartamento-en-venta/el-retiro/retiro_del_viento-det-4435528.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4465869.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283010',
#  '/apartamento-en-venta/el-retiro/retiro-det-4446062.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4464026.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283009',
#  '/apartamento-en-venta/el-retiro/retiro-det-2900198.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4425185.aspx',
#  '/apartamento-en-venta/el-retiro/aldea-det-3612530.aspx?itemid=3612530',
#  '/apartamento-en-venta/el-retiro/pempenao-det-4449622.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4442186.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4464202.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4407409.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4401067.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4445723.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3285757.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4370665.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3770804.aspx',
#  '/apartamento-en-venta/el-retiro/alameda_del_rio-det-4363881.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4401249.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4350685.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx',
#  '/apartamento-en-venta/el-retiro/zona_urbana-det-4418486.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-2499252.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695065',
#  '/apartamento-en-venta/el-retiro/retiro-det-4404067.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4365684.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283009',
#  '/apartamento-en-venta/el-retiro/retiro-det-4359070.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695067',
#  '/apartamento-en-venta/el-retiro/retiro-det-4373358.aspx',
#  '/apartamento-en-venta/el-retiro/salamanca-det-4345256.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4297422.aspx',
#  '/apartamento-en-venta/el-retiro/alameda_del_rio-det-4282647.aspx',
#  '/apartamento-en-venta/el-retiro/aldea-det-3612530.aspx?itemid=3612530',
#  '/apartamento-en-venta/el-retiro/retiro-det-4322472.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695066',
#  '/apartamento-en-venta/el-retiro/pantanillo-det-4281310.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4308626.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283008',
#  '/apartamento-en-venta/el-retiro/retiro-det-4292927.aspx',
#  '/apartamento-en-venta/el-retiro/fizebad-det-4362781.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283010',
#  '/apartamento-en-venta/el-retiro/retiro-det-4365564.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4275463.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695068',
#  '/apartamento-en-venta/el-retiro/zona_urbana-det-4307740.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4322473.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283014',
#  '/apartamento-en-venta/el-retiro/retiro-det-4316799.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4268489.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3277905.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4311804.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4268505.aspx',
#  '/apartamento-en-venta/el-retiro/alameda_del_rio-det-4282574.aspx',
#  '/apartamento-en-venta/el-retiro/retiro_verde-det-3797826.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4268531.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4243580.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4275035.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-2763652.aspx',
#  '/apartamento-en-venta/el-retiro/pempenao-det-4046831.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx',
#  '/apartamento-en-venta/el-retiro/puro_cuero-det-4094359.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4163475.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283008',
#  '/apartamento-en-venta/el-retiro/retiro-det-4161629.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4163674.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695068',
#  '/apartamento-en-venta/el-retiro/retiro-det-4184549.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283010',
#  '/apartamento-en-venta/el-retiro/retiro-det-4184353.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4164544.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4161236.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4090825.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695066',
#  '/apartamento-en-venta/el-retiro/retiro-det-4068334.aspx',
#  '/apartamento-en-venta/el-retiro/aldea-det-3612530.aspx?itemid=3612530',
#  '/apartamento-en-venta/el-retiro/pempenao-det-4036630.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4040105.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695065',
#  '/apartamento-en-venta/el-retiro/represa-det-3547679.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4024500.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695067',
#  '/apartamento-en-venta/el-retiro/retiro-det-4033991.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3563696.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283014',
#  '/apartamento-en-venta/el-retiro/retiro-det-3609468.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4001806.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283009',
#  '/apartamento-en-venta/el-retiro/aldea-det-3883294.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3935596.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3643656.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3935037.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3877890.aspx',
#  '/apartamento-en-venta/el-retiro/fizebad-det-3900304.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3867911.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3825958.aspx',
#  '/apartamento-en-venta/el-retiro/zona_urbana-det-3758192.aspx',
#  '/apartamento-en-venta/el-retiro/el-retiro-det-3819143.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3643422.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3256641.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3283151.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3204490.aspx',
#  '/apartamento-en-venta/el-retiro/aldea-det-3612530.aspx?itemid=3612530',
#  '/apartamento-en-venta/el-retiro/retiro-det-2884276.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-2435531.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283008',
#  '/apartamento-en-venta/el-retiro/retiro-det-2879540.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695065',
#  '/apartamento-en-venta/el-retiro/centro-det-3756837.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3733810.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3731046.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3730743.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695068',
#  '/apartamento-en-venta/el-retiro/retiro-det-3734242.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283009',
#  '/apartamento-en-venta/el-retiro/retiro-det-3734297.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3735028.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695067',
#  '/apartamento-en-venta/el-retiro/retiro-det-3748699.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3737698.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283014',
#  '/apartamento-en-venta/el-retiro/retiro-det-3728741.aspx',
#  '/avanti/el-retiro/proyecto-nuevo-det-4283005.aspx?itemid=4283010',
#  '/apartamento-en-venta/el-retiro/retiro-det-3641675.aspx',
#  '/moka-apartamentos/el-retiro/proyecto-nuevo-det-3695062.aspx?itemid=3695066',
#  '/apartamento-en-venta/el-retiro/retiro-det-4525991.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3548126.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3568755.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3501787.aspx',
#  '/apartamento-en-venta/el-retiro/fizebad-det-3467356.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-4237614.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3294270.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3294300.aspx',
#  '/apartamento-en-venta/el-retiro/retiro-det-3277775.aspx']

# %%
df = pd.DataFrame(all_houses_links, columns=['house link'])

# %%
df.to_csv('houses_link.csv', index=False, encoding='utf-8')

# %%
url = 'https://www.fincaraiz.com.co/apartamentos/venta/el-retiro/?ad=30|1||||1||8|||55|5500013||||||||||||||||1|||1||griddate%20desc||||||'

# %%
print(url.index('|1|'))
# Out:
# 64
